'233616', '163775', '6198', '71124', '162644', '64628', '227330', '230426', '126655', '234011', '147660', '65563', '142634', '160276', '143342', '228452', '87127', '175887', '91729', '180743', '716', '27332', '71654', '105787', '119108', '151330', '54515', '176725', '84141', '106554', '204760', '216257', '15638', '122817', '237953', '119908', '24791', '67073', '124830', '67168', '228295', '124677', '228231', '123', '73076', '194518', '75806', '127519', '10096', '69551', '88642', '113089', '32458', '18019', '165943', '23766', '4208', '171801', '3266', '219869', '214792', '181853', '16138', '208080', '118774', '239816', '173452', '206673', '78308', '158613', '190201', '112910', ...

# %% [markdown]
# ### Some new Python features

# %%
# Iterating through dictionaries
for i in Sitems:
    print(i)
    print(Sitems[i])
# Out:
# milk
# {'1', '5', '2', '4'}
# eggs
# {'1', '3', '4'}
# juice
# {'1', '5', '2'}
# cookies
# {'5', '2'}
# chips
# {'5', '3'}

# %%
# Intersecting sets
# How many transactions contain both eggs and milk?
set1 = Sitems['eggs']
print('Transactions containing eggs:', set1)
set2 = Sitems['milk']
print('Transactions containing milk:', set2)
set3 = set1 & set2
print('Transactions containing both:', set3)
# print('Number of transactions containing both:', len(set3))
# Out:
# Transactions containing eggs: {'1', '3', '4'}
# Transactions containing milk: {'1', '5', '2', '4'}
# Transactions containing both: {'1', '4'}

# %% [markdown]
# ## Shopping dataset - frequent item-sets

# %% [markdown]
# ### Frequent item-sets of two

# %% [markdown]
# #### Print all pairs of items and the number of transactions they occur together in (see what's wrong and fix it)

# %%
for i1 in Sitems:
    for i2 in Sitems:
        common = len(Sitems[i1] & Sitems[i2])
        print([i1, i2, common])
# Out:
# ['milk', 'milk', 4]
# ['milk', 'eggs', 2]
# ['milk', 'juice', 3]
# ['milk', 'cookies', 2]
# ['milk', 'chips', 1]
# ['eggs', 'milk', 2]
# ['eggs', 'eggs', 3]
# ['eggs', 'juice', 1]
# ['eggs', 'cookies', 0]
# ['eggs', 'chips', 1]
# ['juice', 'milk', 3]
# ['juice', 'eggs', 1]
# ['juice', 'juice', 3]
# ['juice', 'cookies', 2]
# ['juice', 'chips', 1]
# ['cookies', 'milk', 2]
# ['cookies', 'eggs', 0]
# ['cookies', 'juice', 2]
# ['cookies', 'cookies', 2]
# ['cookies', 'chips', 1]
# ['chips', 'milk', 1]
# ['chips', 'eggs', 1]
# ['chips', 'juice', 1]
# ['chips', 'cookies', 1]
# ['chips', 'chips', 2]

# %% [markdown]
# #### Now only print pairs that meet support threshold

# %%
support = .3
for i1 in Sitems:
    for i2 in Sitems:
      if i1 < i2:
        common = len(Sitems[i1] & Sitems[i2])
        if common/Snumtrans > support:
          print(i1, '|', i2)
# Out:
# eggs | milk
# juice | milk
# cookies | milk
# cookies | juice

# %% [markdown]
# ### Frequent item-sets of three

# %%
support = .1
for i1 in Sitems:
    for i2 in Sitems:
        for i3 in Sitems:
            if i1 < i2 and i2 < i3:
                common = len(Sitems[i1] & Sitems[i2] & Sitems[i3])
                if common/Snumtrans > support:
                    print(i1, '|', i2, '|', i3)
# Out:
# eggs | juice | milk
# cookies | juice | milk
# chips | juice | milk
# chips | cookies | milk
# chips | cookies | juice

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset frequent item-sets**</font>

# %%
print(Mnumtrans, 'transactions (users)')
print(len(Mitems), 'distinct items (movies)')
# Out:
# 1382 transactions (users)
# 123 distinct items (movies)

# %% [markdown]
# #### Mine for frequent item-sets of three and four items in the Movies dataset. Find a single support threshold where the number of frequent item-sets of three items is more than 10 but less than 20, and the number of frequent item-sets of four items is more than 0.

# %%
# Frequent item-sets of three
from itertools import combinations
support = 0.026
print("Frequent 3-itemsets:")
for i1, i2, i3 in combinations(Mitems.keys(), 3):
    common = Mitems[i1] & Mitems[i2] & Mitems[i3]
    if len(common) / Mnumtrans > support:
        print(f"{i1} | {i2} | {i3}")
# Out:
# Frequent 3-itemsets:
# Boyhood | Big Hero 6 | The Imitation Game
# Boyhood | Big Hero 6 | Inside Out
# Boyhood | Big Hero 6 | Gone Girl
# Boyhood | The Imitation Game | Inside Out
# Boyhood | The Imitation Game | Gone Girl
# Boyhood | The Imitation Game | Fury
# Boyhood | Inside Out | Gone Girl
# Boyhood | Gone Girl | Fury
# Big Hero 6 | The Imitation Game | Inside Out
# Big Hero 6 | The Imitation Game | Gone Girl
# Big Hero 6 | The Imitation Game | Fury
# Big Hero 6 | Inside Out | Gone Girl
# Big Hero 6 | Gone Girl | Fury
# The Imitation Game | Inside Out | Gone Girl
# The Imitation Game | Inside Out | Fury
# The Imitation Game | Gone Girl | Fury
# Inside Out | Gone Girl | Fury

# %%
# Frequent item-sets of four
support = 0.026
print("Frequent 4-itemsets:")
for i1, i2, i3, i4 in combinations(Mitems.keys(), 4):
    common = Mitems[i1] & Mitems[i2] & Mitems[i3] & Mitems[i4]
    if len(common) / Mnumtrans > support:
        print(f"{i1} | {i2} | {i3} | {i4}")
# Out:
# Frequent 4-itemsets:
# Boyhood | Big Hero 6 | The Imitation Game | Gone Girl
# Boyhood | The Imitation Game | Inside Out | Gone Girl
# Boyhood | The Imitation Game | Gone Girl | Fury
# Big Hero 6 | The Imitation Game | Inside Out | Gone Girl
# Big Hero 6 | The Imitation Game | Gone Girl | Fury
# The Imitation Game | Inside Out | Gone Girl | Fury

# %% [markdown]
# ## Shopping dataset - association rules

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of one item, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i in Sitems:
    if len(Sitems[i])/Snumtrans > support:
        frequentLHS.append([i,len(Sitems[i])])
print(frequentLHS)
# Out:
# [['milk', 4], ['eggs', 3], ['juice', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient confidence (see what's wrong and fix it)

# %%
# S -> i

confidence = .5
for lhs in frequentLHS:
    for i in Sitems:
        common = len(Sitems[lhs[0]] & Sitems[i])
        if common/lhs[1] > confidence:
            print(lhs[0], '->', i)
# Out:
# milk -> milk
# milk -> juice
# eggs -> milk
# eggs -> eggs
# juice -> milk
# juice -> juice
# juice -> cookies

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of two items, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
# S = [JUICE, MILK]
support = .5
frequentLHS = []
for i1 in Sitems:
    for i2 in Sitems:
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            if common/Snumtrans > support:
                frequentLHS.append([i1,i2,common])
print(frequentLHS)
# Out:
# [['juice', 'milk', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient confidence

# %%
confidence = .5
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[lhs[1]] & Sitems[i])
            if common/lhs[2] > confidence:
                print(lhs[0], '|', lhs[1], '->', i)
# Out:
# juice | milk -> cookies

# %% [markdown]
# ## Shopping dataset - association rules with lift instead of confidence

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of one item, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i in Sitems:
    if len(Sitems[i])/Snumtrans > support:
        frequentLHS.append([i,len(Sitems[i])])
print(frequentLHS)
# Out:
# [['milk', 4], ['eggs', 3], ['juice', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient lift

# %%
liftthresh = 1
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[i])
            lift = (common/lhs[1]) / (len(Sitems[i])/Snumtrans)
            if lift > liftthresh:
                print(lhs[0], '->', i, ' lift:', lift)
# Out:
# milk -> juice  lift: 1.25
# milk -> cookies  lift: 1.25
# juice -> milk  lift: 1.25
# juice -> cookies  lift: 1.6666666666666665

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of two items, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i1 in Sitems:
    for i2 in Sitems:
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            if common/Snumtrans > support:
                frequentLHS.append([i1,i2,common])
print(frequentLHS)
# Out:
# [['juice', 'milk', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient lift

# %%
liftthresh = 1
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[lhs[1]] & Sitems[i])
            lift = (common/lhs[2]) / (len(Sitems[i])/Snumtrans)
            if lift > liftthresh:
                print(lhs[0], '|', lhs[1], '->', i, ' lift:', lift)
# Out:
# juice | milk -> cookies  lift: 1.6666666666666665

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset association rules**</font>

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and confidence thresholds (need not be the same) so the number of association rules is more than 10 but less than 20.

# %%
# Association rules with three items on the left-hand side
# Hint: Make sure to include the code from the seprate cells above that
#   together implement the two steps of association rule mining
support = 0.03
confidence = 0.65
frequentLHS = []
for i1, i2, i3 in combinations(Mitems.keys(), 3):
    common = Mitems[i1] & Mitems[i2] & Mitems[i3]
    if len(common) / Mnumtrans > support:
        frequentLHS.append([i1, i2, i3, len(common)])
print("Association Rules (Confidence >= {:.0%}):".format(confidence))
for lhs in frequentLHS:
    for rhs in Mitems.keys():
        if rhs not in lhs[:3]:
            common_four = Mitems[lhs[0]] & Mitems[lhs[1]] & Mitems[lhs[2]] & Mitems[rhs]
            if len(common_four) / lhs[3] > confidence:
                print(f"{lhs[0]} | {lhs[1]} | {lhs[2]} -> {rhs}")
# Out:
# Association Rules (Confidence >= 65%):
# Boyhood | Big Hero 6 | The Imitation Game -> Gone Girl
# Boyhood | Big Hero 6 | Gone Girl -> The Imitation Game
# Boyhood | The Imitation Game | Inside Out -> Big Hero 6
# Boyhood | The Imitation Game | Inside Out -> Gone Girl
# Boyhood | The Imitation Game | Fury -> Big Hero 6
# Boyhood | The Imitation Game | Fury -> Gone Girl
# Boyhood | Inside Out | Gone Girl -> The Imitation Game
# Boyhood | Gone Girl | Fury -> The Imitation Game
# Big Hero 6 | The Imitation Game | Fury -> Gone Girl
# Big Hero 6 | Inside Out | Gone Girl -> The Imitation Game
# Big Hero 6 | Gone Girl | Fury -> The Imitation Game
# Big Hero 6 | Gone Girl | Fury -> Inside Out

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and lift thresholds so the number of association rules is more than 10 but less than 20. Only consider lift thresholds > 1.

# %%
# Association rules with three items on the left-hand side
support = 0.015
lift_thresh = 3.3
frequentLHS = []
for i1, i2, i3 in combinations(Mitems.keys(), 3):
    common = Mitems[i1] & Mitems[i2] & Mitems[i3]
    if len(common) / Mnumtrans >= support:
        frequentLHS.append([i1, i2, i3, len(common)])
print(f"Association Rules (Lift > {lift_thresh}):")
for lhs in frequentLHS:
    for rhs in Mitems.keys():
        if rhs not in lhs[:3]:
            common_four = Mitems[lhs[0]] & Mitems[lhs[1]] & Mitems[lhs[2]] & Mitems[rhs]
            s = len(common_four) / Mnumtrans
            lift = (len(common_four) * Mnumtrans) / (lhs[3] * len(Mitems[rhs]))
            if s >= support and lift > lift_thresh:
                print(f"{lhs[0]} | {lhs[1]} | {lhs[2]} -> {rhs}  lift: {lift:.2f}")
# Out:
# Association Rules (Lift > 3.3):
# The Fault in Our Stars | The Imitation Game | Gone Girl -> Boyhood  lift: 3.64
# Boyhood | Big Hero 6 | The Imitation Game -> Fury  lift: 4.92
# Boyhood | Big Hero 6 | Gone Girl -> Fury  lift: 4.83
# Boyhood | The Imitation Game | Inside Out -> Fury  lift: 4.43
# Boyhood | The Imitation Game | Gone Girl -> Fury  lift: 4.11
# Boyhood | The Imitation Game | Gone Girl -> Wild Tales  lift: 4.71
# Boyhood | Inside Out | Gone Girl -> Fury  lift: 4.45
# Big Hero 6 | The Imitation Game | Fury -> Boyhood  lift: 3.86
# Big Hero 6 | Inside Out | Gone Girl -> Fury  lift: 3.42
# Big Hero 6 | Gone Girl | Fury -> Boyhood  lift: 3.81
# The Imitation Game | Inside Out | Gone Girl -> Fury  lift: 3.50
# The Imitation Game | Inside Out | Fury -> Boyhood  lift: 3.57
# The Imitation Game | Gone Girl | Fury -> Boyhood  lift: 3.38
# The Imitation Game | Gone Girl | Wild Tales -> Boyhood  lift: 3.81
# Inside Out | Gone Girl | Fury -> Boyhood  lift: 3.64
